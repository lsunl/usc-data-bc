# %% [markdown]
# ## Scrape win/loss records of NFL teams

# %%
#import dependencies
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
#source: wikipedia
url = "https://en.wikipedia.org/wiki/List_of_all-time_NFL_win%E2%80%93loss_records#Combined_regular_season_and_playoffs"
source = requests.get(url).text

# %%
soup = BeautifulSoup(source, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of all-time NFL win–loss records - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
#   </script>
#   <script>
# ...

# %%
tables_list = soup.find_all('table')

# %%
tables_list[1]
# Out:
# <table border="1" class="wikitable sortable">
# <tbody><tr align="center">
# <th>Rank</th>
# <th>Team</th>
# <th><abbr title="Total games played">GP</abbr></th>
# <th>Won</th>
# <th>Lost</th>
# <th>Tied</th>
# <th>Pct.</th>
# <th>First NFL Season</th>
# <th>Division
# </th></tr>
# <tr align="center">
# <td>1</td>
# <td><a href="/wiki/Dallas_Cowboys" title="Dallas Cowboys">Dallas Cowboys</a></td>
# <td>898</td>
# <td>512</td>
# <td>380</td>
# <td>6</td>
# <td>.573</td>
# <td><a href="/wiki/1960_Dallas_Cowboys_season" title="1960 Dallas Cowboys season">1960</a></td>
# <td bgcolor="#D0E7FF"><a href="/wiki/NFC_East" title="NFC East">NFC East</a>
# </td></tr>
# <tr align="center">
# <td>2</td>
# <td><a href="/wiki/Chicago_Bears" title="Chicago Bears">Chicago Bears</a></td>
# <td>1,386</td>
# <td>761</td>
# <td>583</td>
# <td>42</td>
# <td><abbr title=".5642">.564</abbr></td>
# <td><a href="/wiki/1920_Decatur_Staleys_season" title="1920 Decatur Staleys season">1920</a></td>
# ...

# %%
dfs = pd.read_html(url)

# %%
for df in dfs:
    print(df)
# Out:
#                                   0
# 0  Best win–loss record in division
#        0                        1     2    3     4     5     6  \
# 0   Rank                     Team    GP  Won  Lost  Tied  Pct.
# 1      1           Dallas Cowboys   898  512   380     6  .573
# 2      2            Chicago Bears  1386  761   583    42  .564
# 3      3        Green Bay Packers  1352  743   571    38  .564
# 4      4  New England Patriots[b]   900  500   391     9  .561
# 5      5           Miami Dolphins   816  452   360     4  .556
# 6      6        Minnesota Vikings   886  478   397    11  .546
# 7      7         Baltimore Ravens   368  200   167     1  .545
# 8      8          New York Giants  1321  692   596    33  .536
# 9      9           Denver Broncos   900  476   414    10  .534
# 10    10      San Francisco 49ers  1018  532   472    14  .529
# 11    11    Indianapolis Colts[c]   982  516   459     7  .529
# 12    12      Pittsburgh Steelers  1208  628   558    22  .529
# ...

# %%
regular = dfs[1]
#regular.columns = ["Rank","Team","GP", "Won", "Lost","Tied","Pct","First NFL Season","Division"]
regular.columns = regular.iloc[0,:]
regularcleaned = regular.iloc[1:]
regularcleaned.head()
# Out:
# 0 Rank                     Team    GP  Won Lost Tied  Pct. First NFL Season  \
# 1    1           Dallas Cowboys   898  512  380    6  .573             1960
# 2    2            Chicago Bears  1386  761  583   42  .564             1920
# 3    3        Green Bay Packers  1352  743  571   38  .564             1921
# 4    4  New England Patriots[b]   900  500  391    9  .561             1960
# 5    5           Miami Dolphins   816  452  360    4  .556             1966
#
# 0   Division
# 1   NFC East
# 2  NFC North
# 3  NFC North
# 4   AFC East
# 5   AFC East

# %%
postseason = dfs[3]
postseason.columns = postseason.iloc[0,:]
PScleaned = postseason.iloc[1:]
PScleaned.head()
# Out:
# 0 Rank                  Team  GP Won Lost  Pct. Last playoffappearance  \
# 1    1  New England Patriots  57  37   20  .649                   2018
# 2    2      Baltimore Ravens  24  15    9  .625                   2018
# 3    3     Green Bay Packers  56  34   22  .607                   2016
# 4    4   San Francisco 49ers  50  30   20  .600                   2013
# 5    5   Pittsburgh Steelers  61  36   25  .590                   2017
#
# 0   Division
# 1   AFC East
# 2  AFC North
# 3  NFC North
# 4   NFC West
# 5  AFC North

# %%
combinedseason = dfs[5]
combinedseason.columns = combinedseason.iloc[0,:]
CScleaned = combinedseason.iloc[1:]
CScleaned.head()
# Out:
# 0 Rank                  Team    GP  Won Lost Tied  Pct. First NFL Season  \
# 1    1        Dallas Cowboys   961  547  408    6  .572             1960
# 2    2  New England Patriots   957  537  411    9  .566             1960
# 3    3     Green Bay Packers  1408  777  593   38  .565             1921
# 4    4         Chicago Bears  1422  778  602   42  .562             1920
# 5    5        Miami Dolphins   857  472  381    4  .553             1966
#
# 0   Division
# 1   NFC East
# 2   AFC East
# 3  NFC North
# 4  NFC North
# 5   AFC East

# %%
#load to csv or load into mysql database?
